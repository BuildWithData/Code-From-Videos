# %%
# %config InlineBackend.figure_format = 'retina'

# %%
from analytics import Analytics

analytics = Analytics("MrBeast")
analytics.read()

# %%
analytics.get_videos_per_year()

# %%
analytics.get_videos_per_month(heatmap=True)
# Out:
# <style type="text/css">
# #T_39d8b_row0_col0, #T_39d8b_row0_col3, #T_39d8b_row0_col4, #T_39d8b_row0_col5, #T_39d8b_row0_col6, #T_39d8b_row0_col7, #T_39d8b_row0_col8, #T_39d8b_row0_col9, #T_39d8b_row0_col10, #T_39d8b_row0_col11, #T_39d8b_row1_col1, #T_39d8b_row1_col4, #T_39d8b_row2_col8, #T_39d8b_row5_col3, #T_39d8b_row5_col8, #T_39d8b_row5_col10, #T_39d8b_row9_col4, #T_39d8b_row10_col1, #T_39d8b_row10_col4, #T_39d8b_row11_col1, #T_39d8b_row11_col6, #T_39d8b_row11_col7, #T_39d8b_row11_col8, #T_39d8b_row11_col9, #T_39d8b_row11_col10, #T_39d8b_row11_col11 {
#   background-color: #ffffcc;
#   color: #000000;
#   font-size: 20px;
# }
# ...

# %%
analytics.get_views_from_month(heatmap=True)
# Out:
# <style type="text/css">
# ...

# %%
analytics.get_total_minutes_per_month(heatmap=True)
# Out:
# <style type="text/css">
# #T_50fc7_row0_col0, #T_50fc7_row0_col1, #T_50fc7_row0_col2, #T_50fc7_row0_col3, #T_50fc7_row0_col4, #T_50fc7_row0_col5, #T_50fc7_row0_col6, #T_50fc7_row0_col7, #T_50fc7_row0_col8, #T_50fc7_row0_col9, #T_50fc7_row0_col10, #T_50fc7_row0_col11, #T_50fc7_row1_col1, #T_50fc7_row1_col4, #T_50fc7_row1_col8, #T_50fc7_row1_col9, #T_50fc7_row2_col8, #T_50fc7_row2_col9, #T_50fc7_row2_col11, #T_50fc7_row3_col0, #T_50fc7_row5_col3, #T_50fc7_row5_col4, #T_50fc7_row5_col6, #T_50fc7_row5_col8, #T_50fc7_row5_col10, #T_50fc7_row9_col4, #T_50fc7_row10_col0, #T_50fc7_row10_col1, #T_50fc7_row10_col4, #T_50fc7_row11_col0, #T_50fc7_row11_col1, #T_50fc7_row11_col6, #T_50fc7_row11_col7, #T_50fc7_row11_col8, #T_50fc7_row11_col9, #T_50fc7_row11_col10, #T_50fc7_row11_col11 {
#   background-color: #ffffcc;
#   color: #000000;
#   font-size: 20px;
# }
# ...

# %%
analytics.get_avg_views_from_month(heatmap=True)
# Out:
# <style type="text/css">
# ...
