# %%
from analytics import Analytics


analytics = Analytics("MrBeast")
analytics.read()

# %%
analytics.get_videos_per_year()

# %%
analytics.get_videos_per_month(heatmap=True)
# Out:
# <style type="text/css">
# #T_b73ef_row0_col0, #T_b73ef_row0_col3, #T_b73ef_row0_col4, #T_b73ef_row0_col5, #T_b73ef_row0_col6, #T_b73ef_row0_col7, #T_b73ef_row0_col8, #T_b73ef_row0_col9, #T_b73ef_row0_col10, #T_b73ef_row0_col11, #T_b73ef_row1_col1, #T_b73ef_row1_col4, #T_b73ef_row2_col8, #T_b73ef_row5_col3, #T_b73ef_row5_col8, #T_b73ef_row5_col10, #T_b73ef_row9_col4, #T_b73ef_row10_col1, #T_b73ef_row10_col4, #T_b73ef_row11_col1, #T_b73ef_row11_col7, #T_b73ef_row11_col8, #T_b73ef_row11_col9, #T_b73ef_row11_col10, #T_b73ef_row11_col11 {
#   background-color: #ffffcc;
#   color: #000000;
#   font-size: 20px;
# }
# ...

# %%
analytics.get_views_from_month(heatmap=True)
# Out:
# <style type="text/css">
# ...

# %%
analytics.get_views_from_month(heatmap=True, from_="2020-01-01")
# Out:
# <style type="text/css">
# #T_6fdce_row0_col0 {
#   background-color: #fec662;
#   color: #000000;
#   font-size: 20px;
# }
# #T_6fdce_row0_col1, #T_6fdce_row1_col5 {
#   background-color: #fc6330;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_6fdce_row0_col2 {
#   background-color: #f84628;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_6fdce_row0_col3 {
#   background-color: #feb852;
#   color: #000000;
#   font-size: 20px;
# }
# #T_6fdce_row0_col4 {
#   background-color: #fc5d2e;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_6fdce_row0_col5 {
#   background-color: #fd8439;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_6fdce_row0_col6, #T_6fdce_row0_col8 {
#   background-color: #fd9841;
#   color: #000000;
#   font-size: 20px;
# }
# #T_6fdce_row0_col7 {
#   background-color: #800026;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_6fdce_row0_col9 {
#   background-color: #fa4a29;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_6fdce_row0_col10 {
# ...

# %%
analytics.get_avg_views_from_month(heatmap=True, from_="2020-01-01")
# Out:
# <style type="text/css">
# #T_05ae4_row0_col0 {
#   background-color: #fee289;
#   color: #000000;
#   font-size: 20px;
# }
# #T_05ae4_row0_col1, #T_05ae4_row3_col2 {
#   background-color: #feb651;
#   color: #000000;
#   font-size: 20px;
# }
# #T_05ae4_row0_col2, #T_05ae4_row0_col9 {
#   background-color: #fecb67;
#   color: #000000;
#   font-size: 20px;
# }
# #T_05ae4_row0_col3, #T_05ae4_row3_col0 {
#   background-color: #fec05b;
#   color: #000000;
#   font-size: 20px;
# }
# #T_05ae4_row0_col4 {
#   background-color: #feb54f;
#   color: #000000;
#   font-size: 20px;
# }
# #T_05ae4_row0_col5 {
#   background-color: #fec45f;
#   color: #000000;
#   font-size: 20px;
# }
# #T_05ae4_row0_col6 {
#   background-color: #fea245;
#   color: #000000;
#   font-size: 20px;
# }
# #T_05ae4_row0_col7 {
#   background-color: #feb44e;
#   color: #000000;
#   font-size: 20px;
# }
# #T_05ae4_row0_col8 {
#   background-color: #fedf83;
#   color: #000000;
#   font-size: 20px;
# }
# ...

# %%
analytics.get_total_minutes_per_month(heatmap=True, from_="2020-01-01")
# Out:
# <style type="text/css">
# #T_3665d_row0_col0 {
#   background-color: #fd7836;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_3665d_row0_col1 {
#   background-color: #f84628;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_3665d_row0_col2 {
#   background-color: #a80026;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_3665d_row0_col3, #T_3665d_row1_col10 {
#   background-color: #feb852;
#   color: #000000;
#   font-size: 20px;
# }
# #T_3665d_row0_col4 {
#   background-color: #f03523;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_3665d_row0_col5 {
#   background-color: #f33b25;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_3665d_row0_col6 {
#   background-color: #feaf4b;
#   color: #000000;
#   font-size: 20px;
# }
# #T_3665d_row0_col7 {
#   background-color: #800026;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_3665d_row0_col8 {
#   background-color: #e7231e;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_3665d_row0_col9, #T_3665d_row2_col11 {
# ...

# %%
analytics.get_avg_minutes_per_month(heatmap=True, from_="2020-01-01")
# Out:
# <style type="text/css">
# #T_8950b_row0_col0, #T_8950b_row0_col3, #T_8950b_row0_col8, #T_8950b_row2_col11, #T_8950b_row3_col2, #T_8950b_row3_col3 {
#   background-color: #fd933f;
#   color: #000000;
#   font-size: 20px;
# }
# #T_8950b_row0_col1, #T_8950b_row0_col5, #T_8950b_row2_col9, #T_8950b_row2_col10, #T_8950b_row3_col4 {
#   background-color: #fc5b2e;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_8950b_row0_col2, #T_8950b_row0_col4, #T_8950b_row1_col7 {
#   background-color: #f94828;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_8950b_row0_col6, #T_8950b_row2_col3 {
#   background-color: #fd8239;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_8950b_row0_col7, #T_8950b_row0_col10, #T_8950b_row1_col3, #T_8950b_row1_col5, #T_8950b_row2_col6, #T_8950b_row2_col8, #T_8950b_row3_col5 {
#   background-color: #fd6e33;
#   color: #f1f1f1;
#   font-size: 20px;
# }
# #T_8950b_row0_col9, #T_8950b_row2_col2 {
#   background-color: #feb651;
#   color: #000000;
#   font-size: 20px;
# ...

# %%
analytics.get_top_videos_by_views(5)
# Out:
#             id                                     title      views  \
# 0  0e3GPea1Tyg         $456,000 Squid Game In Real Life!  457439622
# 1  zxYjTTXc-J8        Last To Leave Circle Wins $500,000  311083603
# 2  r7zJ8srwwjk  I Spent 50 Hours In Solitary Confinement  277109121
# 3  9bqk6ZUsKyA             I Spent 50 Hours Buried Alive  274845053
# 4  GLoeAJUcz38        Press This Button To Win $100,000!  258737429
#
#   publish_date                                        description keywords  \
# 0   2021-11-24  MAKE SURE YOU WATCH UNTIL GLASS BRIDGE IT'S IN...       []
# 1   2021-08-31  THIS WAS THE CRAZIEST THING IVE EVER DONE!\n\n...       []
# 2   2020-05-30  i borderline went crazy about 30 hours in...\n...       []
# 3   2021-03-27  This was the most insane thing I’ve ever done\...       []
# 4   2020-11-14  Push the red subscribe button and you could al...       []
#
#    length  year  month    minutes
# 0    1541  2021     11  25.683333
# 1    1063  2021      8  17.716667
# ...
